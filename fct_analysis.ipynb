# %%
import numpy as np
filename = "../ESN/DATA/multipods/W5_37/DATA_zeropod_W5_1/FCT.txt"
data = np.loadtxt(filename, delimiter=' ')

# %%
flow_size = data[:, 4]
slow_down = data[:, 5]
# print(flow_size)
# Out:
# [ 50154. 154582.  43954. ...  20834.   2767. 994634.]
